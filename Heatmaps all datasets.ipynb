# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
c1 = pd.read_excel(
    r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C1\CSF extracellular original.xlsx",
    index_col=0
)

# %%
c1_trans = c1.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c1_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C1", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
s2= pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set S2\A prot net prot family.xlsx",
    index_col=0
)

# %%
s2_trans = s2.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    s2_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set S2", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
s5=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set S5\Olfactory prot families.xlsx", index_col=0)

# %%
s5_trans = s5.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    s5_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set S5", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
c6=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C6\label free prot families.xlsx", index_col=0)

# %%
c6_trans = c6.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c6_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C6", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
b7=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set B7\Char Mann-W prot families.xlsx", index_col=0)

# %%
b7_trans = b7.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    b7_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set B7", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
c8= pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C8\Exo T-test prot families.xlsx", index_col=0)

# %%
c8_trans = c8.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c8_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C8", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
c9=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C9\Cereb prot family.xlsx", index_col=0)

# %%
c9_trans = c9.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c9_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C9", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
b10=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set B10\ML Mann-W prot family.xlsx", index_col=0)

# %%
b10_trans = b10.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    b10_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set B10", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
s11=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set S11\TDP-43 prot family.xlsx", index_col=0)

# %%
s11_trans = s11.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    s11_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set S11", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
c12=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C12\Discovery prot family.xlsx", index_col=0)

# %%
c12_trans = c12.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c12_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C12", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
c13=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set C13\Biomarkers protein family.xlsx", index_col=0)

# %%
c13_trans = c13.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    c13_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set C13", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
l14=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set L14\Integrative prot family.xlsx", index_col=0)
l14.head()
# Out:
#             Control 1  Control 2     ALS 1     ALS 2     ALS 3     ALS 4
# Gene names
# NRGN         155410.0   157970.0   47724.0   52276.0   49919.0   44585.0
# CPLX1        484820.0   483220.0  208700.0  213990.0  215570.0  188200.0
# TIMM8A        68902.0    68335.0   27662.0   28960.0   29665.0   32049.0
# SNCB         669920.0   661820.0  243360.0  293570.0  273280.0  267440.0
# TOMM40L      266440.0   267320.0  178360.0  181920.0  178140.0  188280.0

# %%
l14_log2 = np.log2(l14)

# %%
l14_log2_trans = l14_log2.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    l14_log2_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set L14", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
l15=pd.read_excel(r"C:\Users\Client\OneDrive - Queen Mary, University of London\PhD Shared folder\Datasets\Set L15\AnswerALS Mann-W no scale prot families.xlsx", index_col=0)
l15.head()
# Out:
#                ALS 1     ALS 2     ALS 3     ALS 4     ALS 5     ALS 6  \
# Gene names
# UBA6         2626.16   2588.04   2507.03   2913.20   2865.30   3357.25
# ESYT2        3985.19   3860.51   3931.82   3926.29   4940.13   4587.97
# SHOT1       17934.00  16037.20  18116.60  15280.10  19765.40  14493.70
# ILVBL       15656.00  19963.40  14834.90  15015.00  15356.70  18380.80
# SPD2B        5242.79   5763.16   5432.44   4587.41   5445.52   5633.45
#
#                ALS 7     ALS 8     ALS 9    ALS 10  ...  Control 11  \
# Gene names                                          ...
# UBA6         2967.33   3116.56   3013.63   2639.38  ...     2047.42
# ESYT2        3472.10   4155.66   3633.70   5932.34  ...     4071.36
# SHOT1       15945.10  15707.10  17674.20  23334.40  ...    17266.60
# ILVBL       14549.00  14402.90  17603.90  21581.90  ...    15379.40
# SPD2B        5827.67   5705.44   5218.67   4173.28  ...     5780.46
#
# ...

# %%
l15_log2 = np.log2(l15)

# %%
l15_log2_trans = l15_log2.transpose()

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(
    l15_log2_trans,
    annot=False,
    cmap="viridis",
    cbar_kws={"label": "Expression level"}
)

plt.xlabel("Gene names", fontsize=16)
plt.ylabel("Samples", fontsize=16)
plt.title("Heatmap of Protein Expression: Set L15", fontsize=20)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
